# %%
import numpy as np 
import pandas as pd 
import ast
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138

# %%
avg,avg1,avg2=[dice6],[dice6],[dice6]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\s_l_up_6dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\avg_random_ladders_snakes_fixed10.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
with open("results\\avg_random_ladders_snakes_fixed5.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0

# %%
len(avg)

# %%
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(30,int(round(max(avg),0))+1)
plt.xlim(0,len(avg2)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="random length")
plt.xlabel('number of ladders and snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="length fixed at 10")
bx.plot(range(0,len(avg2)),avg2,color="green",label="length fixed at 5")
plt.xticks(range(0,len(avg)+1))
#plt.yticks(range(30,1000,50))
plt.yticks(range(30,int(round(max(avg),0))+1,1))
plt.legend()
plt.savefig("results\images\images\\fixed10_5_combine.png")

# %%
avg,avg1,avg2=[dice6],[dice6],[dice6]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_snakes.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_random_snakes10.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
with open("results\\average_random_snakes5.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0

# %%
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(0,int(round(max(avg2),0))+1)
plt.xlim(0,len(avg2)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="random length of snake")
plt.xlabel('number of snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="length of snakes equal to 10")
bx.plot(range(0,len(avg2)),avg2,color="green",label="length of snakes equal to 5")
plt.xticks(range(0,len(avg2)+1))
plt.yticks(range(50,1000,50))
#plt.yticks(range(0,int(round(max(avg2),0))+1,50))
plt.legend()
plt.savefig("results\images\images\\avg_snakes1.png")

# %%
avg,avg1,avg2=[dice6],[],[]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_snakes.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
"""with open("results\\average_random_snakes10.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
with open("results\\average_random_snakes5.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0"""

# %%
min(avg)

# %%
figure(num=None, figsize=(20, 30), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(0,int(round(max(avg),0))+1)
plt.xlim(0,len(avg)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="random length of snake")
plt.xlabel('number of snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
#ax.plot(range(1,len(avg1)+1),avg1,color="blue",label="length of snakes equal to 10")
#bx.plot(range(1,len(avg2)+1),avg2,color="green",label="length of snakes equal to5")
plt.xticks(range(0,len(avg)+1))
#plt.yticks(range(50,1000,50))
plt.yticks(range(0,int(round(max(avg),0))+1,50))
plt.legend()
plt.savefig("results\images\images\\average_snake_only_random.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
avg,avg1,avg2=[dice100],[dice6],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\avg_random_snake_up100.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_snakes.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
with open("results\\avg_random_snake_up15.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0

# %%
figure(num=None, figsize=(20, 20), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(20,int(round(max(avg2),0))+1)
plt.xlim(0,len(avg)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="die size is 100")
plt.xlabel('number of snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="die size is 6")
bx.plot(range(0,len(avg2)),avg2,color="green",label="die size is 15")
plt.xticks(range(0,len(avg)+1))
#plt.yticks(range(50,1000,50))
plt.yticks(range(0,int(round(max(avg2),0))+1,10))
plt.legend()
plt.savefig("results\images\images\\avg_snakes_dices.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
avg,avg1,avg2=[dice6],[dice2],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\s_l_up_6dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_ladderssnakes2dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
"""with open("results\\avg_random_snake_up15.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0"""

# %%
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(30,int(round(max(avg),0))+1)
plt.xlim(0,len(avg)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="one die")
plt.xlabel('number of snakes and ladders')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="pair of dice")
#bx.plot(range(0,len(avg2)),avg2,color="green",label="die size is 15")
plt.xticks(range(0,len(avg)+1))
#plt.yticks(range(50,1000,50))
plt.yticks(range(30,int(round(max(avg),0))+1,1))
plt.legend()
plt.savefig("results\images\images\\avg_snake_ladder_2dice_combine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
avg,avg1,avg2=[dice6],[dice2],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_snakes.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_random_snake2dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(0,2000)
plt.xlim(0,len(avg)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="one die")
plt.xlabel('number of snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="pair of dice")
plt.xticks(range(0,len(avg)+1))
plt.yticks(range(0,2000,50))
plt.legend()
plt.savefig("results\images\images\\avg_snake_2dice_combine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
avg,avg1,avg2=[dice100],[dice6],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_ladders100.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_random_6dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
with open("results\\average_length_ladders15.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0
#graph
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(20,int(round(max(avg),0))+1)
plt.xlim(0,len(avg)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="die size is 100")
plt.xlabel('number of ladders')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="die size is 6")
bx.plot(range(0,len(avg2)),avg2,color="green",label="die size is 15")
plt.xticks(range(0,len(avg)+1))
#plt.yticks(range(50,1000,50))
plt.yticks(range(0,int(round(max(avg),0))+1,5))
plt.legend()
plt.savefig("results\images\images\\avg_ladders_dice_combine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
avg,avg1,avg2=[dice6],[dice6],[dice6]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_random_6dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_ladders10.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
with open("results\\average_length_ladders5.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0
#graph
figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(0,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg2)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="random ladders")
plt.xlabel('number of ladders')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="random ladders with length equals to 10")
bx.plot(range(0,len(avg2)),avg2,color="green",label="random ladders with length equals to 5")
plt.xticks(range(0,len(avg2)))
#plt.yticks(range(50,1000,50))
plt.yticks(range(0,int(round(max(avg),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\avg_ladders_combine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
avg,avg1,avg2=[dice6],[dice2],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_random_6dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_ladders2dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(0,int(round(max(avg1)+2,0)))
plt.xlim(0,len(avg)+1)
plt.plot(range(0,len(avg)),avg,color='red',label="one die")
plt.xlabel('number of ladders')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="pair of dice")
plt.xticks(range(0,len(avg)+1))
plt.yticks(range(0,int(round(max(avg1),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\avg_ladders_2dice_combine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice6],[dice6],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\s_l_up_6dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_random_not_exactly100.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(20,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="game ends at exactly 100")
plt.xlabel('number of snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="game ends above 100")
plt.xticks(range(0,len(avg)))
plt.yticks(range(20,int(round(max(avg),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\avg_combine_notexactly100.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice100],[harmonic100],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\avg_random_snake_up100.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_snakes_100harmonic.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(0,int(round(max(avg1)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="Uniform distribution 100-sides die")
plt.xlabel('number of snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="Harmonic distribution 100-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(0,int(round(max(avg1),0))+2,5))
plt.legend()
plt.savefig("results\images\images\\avg_combine_snakes_harmonic100.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice100],[harmonic100],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_ladders100.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_ladders_100harmonic.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(10,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="uniform distribution 100-sides die")
plt.xlabel('number of ladders')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="harmonic distribution 100-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(10,int(round(max(avg),0))+2,5))
plt.legend()
plt.savefig("results\images\images\\avg_combine_ladders_harmonic100.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice100],[harmonic100],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\s_l_up_100dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_ladders_snakes_100harmonic.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(15,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="uniform distribution 100-sides die")
plt.xlabel('number of ladders and snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="harmonic distribution 100-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(15,int(round(max(avg),0))+2,2))
plt.legend()
plt.savefig("results\images\images\\avg_combine_harmonic100.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice15],[harmonic100],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\s_l_up_15dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_ladders_snakes_100harmonic.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(15,int(round(max(avg1)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="uniform distribution 15-sides die")
plt.xlabel('number of ladders and snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="harmonic distribution 100-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(15,int(round(max(avg1),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\avg_combine_15dice_harmonic100.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice2],[dice11],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_ladderssnakes2dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_random_11dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(15,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="pair of dice")
plt.xlabel('number of ladders and snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="uniform distribution 11-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(15,int(round(max(avg),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\11_12_2dice_combine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice2],[dice11],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_ladders2dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_ladder_11dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(10,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="pair of dice")
plt.xlabel('number of ladders')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="uniform distribution 11-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(10,int(round(max(avg),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\11_12_2dice_ladderscombine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice2],[dice11],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_snakes_2dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_snakes_11dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(15,2120)
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="pair of dice")
plt.xlabel('number of  snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="uniform distribution 11-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(15,2120,50))
plt.legend()
plt.savefig("results\images\images\\11_12_2dice_snakescombine.png")

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice2],[dice11],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\\average_length_ladders2dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\\average_length_ladder_11dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
#graph
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(15,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red',label="pair of dice")
plt.xlabel('number of ladders')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="uniform distribution 11-sides die")
plt.xticks(range(0,len(avg)))
plt.yticks(range(15,int(round(max(avg),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\11_12_2dice_ladderscombine.png")

# %%
import numpy as np 
import pandas as pd 
import ast
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import os,sys
dir_path=os.path.dirname("D:\\maths\\thesis\\algo_thesis\\game")
sys.path.append(dir_path)
from markov_chain.markov_og import Markov
from game.snake_ladder import Snakes

import ast
lists=[]
avg=[]


for i in range(2,3):
    snake=Snakes(0,0)
    markov=Markov(69,100)
    trans=markov.transition_harmonic()
    sl=markov.snake_ladder(trans,snake.snakes_ladders)
    result=markov.fundamental_form(sl)
    s=markov.number_visit(sl)

# %%
result
# Out:
# 21.75489139337484

# %%
figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(0,int(round(max(s[0])+0.25,0)))
plt.xlim(0,101)
plt.plot(range(0,len(s[0])),s[0],color='red')
plt.xlabel('number of square')
plt.ylabel('expected number of visits in the game')
plt.xticks(range(0,101,2))
plt.savefig("results\images\images\\visits_harmonic.png")

# %%
s[0][99]
# Out:
# 1.6841969088727768

# %%
import numpy as np
np.argsort(s[0])[::-1][:5]
# Out:
# array([99, 97,  0, 78, 91], dtype=int64)

# %%
np.argsort(s[0])[:5]
# Out:
# array([49, 98, 51, 36, 28], dtype=int64)

# %%
avg,avg1=[],[]
with open("results\markov1_100.txt","r") as fp:
    for f in fp:
        avg.append(float(f.strip()))
with open("results\simulation2_100.txt","r") as fp1:
    for f in fp1:
        avg1.append(float(f.strip()))

figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
sns.set_style('whitegrid')
matplotlib.rcParams.update({'font.size':16})
plt.ylim(15,int(max(avg))+5)
plt.xlim(2,len(avg)+2)
plt.plot(range(2,len(avg)+2),avg,color='red',label="markov chain analysis")
plt.xlabel('sides of die')
plt.ylabel('average length of the game')
ax=plt.subplot()
#bx=plt.subplot()
ax.plot(range(2,len(avg1)+2),avg1,color="blue",label="python simulation")
#bx.plot(range(2,len(avg2)+2),avg2,color="green",label="python simulation")
plt.xticks(range(2,len(avg)+2,2))
#plt.yticks(range(30,1000,50))
plt.yticks(range(15,int(max(avg))+5,2))
plt.legend()
plt.savefig("results\images\images\\simulation_combine_og.png")
# Out:
# <ipython-input-9-78a2106ae686>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.subplot()

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
harmonic100=18.66278125336158
avg,avg1,avg2=[dice6],[dice11],[dice15]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\s_l_up_6dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0

#graph
figure(num=None, figsize=(20, 18), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(30,int(round(max(avg)+2,0)))
plt.xlim(0,len(avg))
plt.plot(range(0,len(avg)),avg,color='red')
plt.xlabel('number of ladders and snakes')
plt.ylabel('average length of the game')
plt.xticks(range(0,len(avg)))
plt.yticks(range(30,int(round(max(avg),0))+2,1))
plt.legend()
plt.savefig("results\images\images\\avg_snake_and_ladder_up.png")
# Out:
# No handles with labels found to put in legend.

# %%
dice15=26.208334450572586
dice6=33.33333333333334
dice100=99.9999999999999
dice2=37.91801526337226
dice11=26.388888908669138
avg,avg1,avg2=[dice6],[dice15],[dice100]
accum,accum1,accum2=0,0,0
count,count1,count2=0,0,0
above,above1,above2=0,0,0
with open("results\s_l_up_6dice.txt","r") as fp:
    for f in fp:
        count+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum+=float(f.strip())
        else:
            above+=1
        if count==1000:
            count=count-above
            avg.append(accum/count)
            above,count,accum=0,0,0
with open("results\s_l_up_15dice.txt","r") as fp:
    for f in fp:
        count1+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum1+=float(f.strip())
        else:
            above1+=1
        if count1==1000:
            count1=count1-above1
            avg1.append(accum1/count1)
            above1,count1,accum1=0,0,0
with open("results\s_l_up_100dice.txt","r") as fp:
    for f in fp:
        count2+=1
        if float(f.strip())<10000 and float(f.strip())>0:
            accum2+=float(f.strip())
        else:
            above2+=1
        if count2==1000:
            count2=count2-above2
            avg2.append(accum2/count2)
            above2,count2,accum2=0,0,0
#graph
figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
matplotlib.rcParams.update({'font.size':16})
sns.set_style('whitegrid')
plt.ylim(20,int(round(max(avg2)+2,0)))
plt.xlim(0,len(avg2))
plt.plot(range(0,len(avg)),avg,color='red',label="6-sides die")
plt.xlabel('number of ladders and snakes')
plt.ylabel('average length of the game')
ax=plt.subplot()
bx=plt.subplot()
ax.plot(range(0,len(avg1)),avg1,color="blue",label="15-sides die")
bx.plot(range(0,len(avg2)),avg2,color="green",label="100-sides die")
plt.xticks(range(0,len(avg2)))
#plt.yticks(range(50,1000,50))
plt.yticks(range(20,int(round(max(avg2),0))+2,4))
plt.legend()
plt.savefig("results\images\images\\avg_combine.png")
# Out:
# <ipython-input-19-7e2ac0fea25c>:52: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.subplot()
# <ipython-input-19-7e2ac0fea25c>:53: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   bx=plt.subplot()

# %%
avg,avg1=[],[]
with open("results\\average_length_og_1_100dice.txt","r") as fp:
    for f in fp:
        avg.append(float(f.strip()))
with open("results\\average_length_og_1_100harmonic.txt","r") as fp1:
    for f in fp1:
        avg1.append(float(f.strip()))

figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
sns.set_style('whitegrid')
matplotlib.rcParams.update({'font.size':16})
plt.ylim(15,int(max(avg))+5)
plt.xlim(2,len(avg)+2)
plt.plot(range(2,len(avg)+2),avg,color='red',label="uniform distribution die")
plt.xlabel('sides of die')
plt.ylabel('average length of the game')
ax=plt.subplot()
#bx=plt.subplot()
ax.plot(range(2,len(avg1)+2),avg1,color="blue",label="harmonic distribution die")
#bx.plot(range(2,len(avg2)+2),avg2,color="green",label="python simulation")
plt.xticks(range(2,len(avg)+2,2))
#plt.yticks(range(30,1000,50))
plt.yticks(range(15,int(max(avg))+5,2))
plt.legend()
plt.savefig("results\images\images\\avg_combine_1_100ogset.png")
# Out:
# <ipython-input-21-74bf7c841645>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.subplot()

# %%
avg,avg1=[],[]
with open("results\\average_length_mosl_1_100dice.txt","r") as fp:
    for f in fp:
        avg.append(float(f.strip()))
with open("results\\average_length_mosl_1_100harmonic.txt","r") as fp1:
    for f in fp1:
        avg1.append(float(f.strip()))

figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
sns.set_style('whitegrid')
matplotlib.rcParams.update({'font.size':16})
plt.ylim(15,int(max(avg))+5)
plt.xlim(2,len(avg)+2)
plt.plot(range(2,len(avg)+2),avg,color='red',label="uniform distribution die")
plt.xlabel('sides of die')
plt.ylabel('average length of the game')
ax=plt.subplot()
#bx=plt.subplot()
ax.plot(range(2,len(avg1)+2),avg1,color="blue",label="harmonic distribution die")
#bx.plot(range(2,len(avg2)+2),avg2,color="green",label="python simulation")
plt.xticks(range(2,len(avg)+2,2))
#plt.yticks(range(30,1000,50))
plt.yticks(range(15,int(max(avg))+5,2))
plt.legend()
plt.savefig("results\images\images\\avg_combine_nosl_1_100ogset.png")
# Out:
# <ipython-input-22-22816c14e5ac>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.subplot()
